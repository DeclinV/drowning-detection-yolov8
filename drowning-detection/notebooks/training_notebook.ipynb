# %%
# !nvidia-smi
# Out:
# Mon Sep  7 03:43:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 596.36                 Driver Version: 596.36         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:29:00.0  On |                  N/A |
# | 40%   28C    P8            N/A  /  115W |    1654MiB /   8188MiB |     21%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.142  Python-3.13.15 torch-2.14.0+cpu CPU (AMD Ryzen 5 5600X 6-Core Processor)
# Setup complete  (12 CPUs, 31.9 GB RAM, 870.0/930.5 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.train(
    data='datasets/Drowning Detection.v1i.yolov8/data.yaml',
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.142  Python-3.13.15 torch-2.14.0+cpu CPU (AMD Ryzen 5 5600X 6-Core Processor)
# ...

# %%
Image(filename="runs/detect/train/confusion_matrix.png", width=600)

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')

# Run on a video file, saves an annotated version automatically
results = model.predict(
    source="demo_input/sample_footage.mp4",
    save=True,
    conf=0.5  # confidence threshold - only show detections model is at least 50% sure of
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/7153) C:\Users\Neon\Downloads\YTDown.com_YouTube_A-5-year-old-child-drowns-in-a-swimming-_Media_zuZIfy4aBEY_001_480p.mp4: 384x640 2 Swimmings, 199.3ms
# video 1/1 (frame 2/7153) C:\Users\Neon\Downloads\YTDown.com_YouTube_A-5-year-old-child-drowns-in-a-swimming-_Media_zuZIfy4aBEY_001_480p.mp4: 384x640 2 Swimmings, 23.9ms
# ...
